# %%
import osmnx as ox
import geopandas
import pandas as pd
import googlemaps
import time
import requests # requests through url
import json
import csv


# %matplotlib inline
ox.config(log_console=True, use_cache=True)
ox.__version__
# Out:
# '0.11.4'

# %%
locs = pd.read_csv('data/locations.csv',usecols = ['Location','Lat','Lng'])
display(locs)
# Out:
#          Location        Lat         Lng
# 0     Mission Bay  37.768831 -122.389311
# 1    Hayes Valley  37.776861 -122.423333
# 2  Kendall Square  42.362436  -71.086200
# 3  Pearl District  45.526594 -122.682297
# 4  Uptown Oakland  37.808939 -122.268494
# 5      Grand Lake  37.810389 -122.246933

# %%
# load retail search list
retail_list = pd.read_csv('data/list retail.csv',header = None)
retail_list = [i for i in retail_list[0]]
print (retail_list)
# Out:
# ['art_gallery', 'bakery', 'bank', 'bar', 'beauty_salon', 'bicycle_store', 'book_store', 'bowling_alley', 'cafe', 'clothing_store', 'convenience_store', 'department_store', 'drugstore', 'electronics_store', 'florist', 'furniture_store', 'grocery_or_supermarket', 'gym', 'hair_care', 'hardware_store', 'home_goods_store', 'jewelry_store', 'liquor_store', 'meal_takeaway', 'movie_rental', 'movie_theater', 'museum', 'night_club', 'pharmacy', 'pet_store', 'restaurant', 'shoe_store', 'shopping_mall', 'spa', 'store', 'supermarket']

# %%
# load trasit search list
transit_list = pd.read_csv('data/list transit.csv',header = None)
transit_list = [i for i in transit_list[0]]
print (transit_list)
# Out:
# ['bus_station', 'light_rail_station', 'subway_station', 'train_station', 'transit_station']

# %%
def get_netwrok_shapefile(file, distance, network_type):   
    locs = file
    d = distance
    nx_type = network_type
    for index, rows in locs.iterrows(): 

        latitude =rows.Lat
        longitude= rows.Lng
        location_point = (latitude,longitude)

        # query from point
        G = ox.graph_from_point(location_point, distance=d, distance_type='bbox', network_type= nx_type,simplify=True)
        G = ox.project_graph(G)
        # save shapefile
        filename = 'network-{}-{}'.format(rows.Location,nx_type)
        ox.save_graph_shapefile(G, filename=filename)

        # plot network graph
        print(f'{rows.Location} get!')
        #fig, ax = ox.plot_graph(G, node_size=30, node_color='#66cc66')

# %%
get_netwrok_shapefile(file=locs,distance=1000,network_type = 'walk')
# Out:
# Mission Bay get!
# Hayes Valley get!
# Kendall Square get!
# Pearl District get!
# Uptown Oakland get!
# Grand Lake get!

# %%
get_netwrok_shapefile(file=locs,distance=1000,network_type = 'drive')
# Out:
# Mission Bay get!
# Hayes Valley get!
# Kendall Square get!
# Pearl District get!
# Uptown Oakland get!
# Grand Lake get!

# %%
def search_places_by_coordinate(key, location, radius, types):
    
    endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    places = []
    params = {
        'location': location,
        'radius': radius,
        'types': types,
        'key': key
    }
    res = requests.get(endpoint_url, params = params)
    
    results =  json.loads(res.content)
    places.extend(results['results'])
    time.sleep(2)
    print('page1',len(places))
    while "next_page_token" in results:
        params['pagetoken'] = results['next_page_token'],
        res = requests.get(endpoint_url, params = params)
        results = json.loads(res.content)
        places.extend(results['results'])
        time.sleep(2)
    print('all pages',len(places))
    return places

# %%
def json_save_to_csv(places, filename):
    all_places=[('Name','Place_id','Y','X','Type')]
    for place in places:
        name = place['name']
        place_id = place['place_id']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        types = place['types']
        data = name, place_id, lat, lng, types
        all_places.append(data)
    # print(all_places)

    with open(filename, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        for i in all_places:
            wr.writerow(i)

# %%
p = []
for retail in retail_list:
    print(retail)
    p_i= search_places_by_coordinate(key='', 
                                     location='37.768831, -122.389311', 
                                     radius = 50, 
                                     types= retail)
    p.extend(p_i)
print(p)
json_save_to_csv(places = p , filename="mission bay_retail.csv")
# Out:
# art_gallery
# page1 8
# 8
# bakery
# page1 4
# 4
# bar
# page1 1
# 1
# beauty_salon
# page1 9
# 9
# bicycle_store
# page1 1
# 1
# book_store
# page1 1
# 1
# bowling_alley
# page1 0
# 0
# clothing_store
# page1 13
# 13
# convenience_store
# page1 0
# 0
# department_store
# page1 1
# 1
# drugstore
# page1 0
# 0
# electronics_store
# page1 8
# 8
# florist
# page1 0
# 0
# furniture_store
# page1 2
# 2
# gym
# page1 14
# 14
# hair_care
# page1 4
# 4
# hardware_store
# page1 0
# 0
# home_goods_store
# page1 15
# 15
# jewelry_store
# page1 4
# 4
# liquor_store
# page1 0
# 0
# meal_takeaway
# page1 2
# 2
# movie_rental
# page1 0
# 0
# movie_theater
# page1 0
# 0
# museum
# page1 1
# 1
# night_club
# page1 1
# 1
# pet_store
# page1 0
# 0
# shoe_store
# page1 2
# 2
# shopping_mall
# page1 0
# 0
# spa
# page1 5
# 5
# [{'geometry': {'location': {'lat': 37.77037420000001, 'lng': -122.3872691}, 'viewport': {'northeast': {'lat': 37.7717094302915, 'lng': -122.3861604697085}, 'southwest': {'lat': 37.7690114697085, 'lng': -122.3888584302915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': '736a88d60aee70274e0455b6d7083afcd200adf6', 'name': "Créa'Can", 'place_id': 'ChIJq6p6_sR_j4ARx2xjD29Valo', 'plus_code': {'compound_code': 'QJC7+43 SoMa, San Francisco, CA, United States', 'global_code': '849VQJC7+43'}, 'reference': 'ChIJq6p6_sR_j4ARx2xjD29Valo', 'scope': 'GOOGLE', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'vicinity': '500 Terry A Francois Boulevard, San Francisco'}, {'geometry': {'location': {'lat': 37.77064999999999, 'lng': -122.387301}, 'viewport': {'northeast': {'lat': 37.7720805302915, 'lng': -122.3860373197085}, 'southwest': {'lat': 37.7693825697085, 'lng': -122.3887352802915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'af9f0462e4de5d5fcdb998b4a270c4f9f7f2d24a', 'name': 'Barn Owl Bothy', 'place_id': 'ChIJq6p6_sR_j4ARf5VJJx3GYcg', 'plus_code': {'compound_code': 'QJC7+73 SoMa, San Francisco, CA, United States', 'global_code': '849VQJC7+73'}, 'reference': 'ChIJq6p6_sR_j4ARf5VJJx3GYcg', 'scope': 'GOOGLE', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'vicinity': '500 Terry A Francois Boulevard, San Francisco'}, {'geometry': {'location': {'lat': 37.7703718, 'lng': -122.3871248}, 'viewport': {'northeast': {'lat': 37.7717082302915, 'lng': -122.3860883197085}, 'southwest': {'lat': 37.7690102697085, 'lng': -122.3887862802915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'beb815983c57eb7356d22501970a89ffd27e745e', 'name': 'artis magna', 'place_id': 'ChIJq6p6_sR_j4ARgqT22-CVOpo', 'reference': 'ChIJq6p6_sR_j4ARgqT22-CVOpo', 'scope': 'GOOGLE', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'vicinity': '500 Terry A Francois Boulevard, San Francisco'}, {'geometry': {'location': {'lat': 37.7703718, 'lng': -122.3871248}, 'viewport': {'northeast': {'lat': 37.7717082302915, 'lng': -122.3860883197085}, 'southwest': {'lat': 37.7690102697085, 'lng': -122.3887862802915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': '7778e9e74a85986e056bd9b723b58b3d1418a7fa', 'name': 'Lee Wright', 'place_id': 'ChIJq6p6_sR_j4ARwOrfgsxLX3c', 'reference': 'ChIJq6p6_sR_j4ARwOrfgsxLX3c', 'scope': 'GOOGLE', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'vicinity': '500 Terry A Francois Boulevard, San Francisco'}, {'geometry': {'location': {'lat': 37.7703718, 'lng': -122.3871248}, 'viewport': {'northeast': {'lat': 37.7717082302915, 'lng': -122.3860883197085}, 'southwest': {'lat': 37.7690102697085, 'lng': -122.3887862802915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'af4883d05dfde8cdadec044afd5f4919e993ddc1', 'name': 'James Elliott', 'place_id': 'ChIJq6p6_sR_j4ARgFhWcOdplGI', 'reference': 'ChIJq6p6_sR_j4ARgFhWcOdplGI', 'scope': 'GOOGLE', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'vicinity': '500 Terry A Francois Boulevard, San Francisco'}, {'geometry': {'location': {'lat': 37.77037420000001, 'lng': -122.3872691}, 'viewport': {'northeast': {'lat': 37.7717094302915, 'lng': -122.3861604697085}, 'southwest': {'lat': 37.7690114697085, 'lng': -122.3888584302915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'fa6112b59a08abf5c43f3a29257bf3e406aa854b', 'name': 'Art de LaShae', 'place_id': 'ChIJq6p6_sR_j4ARpC7fCj77Z4A', 'plus_code': {'compound_code': 'QJC7+43 SoMa, San Francisco, CA, United States', 'global_code': '849VQJC7+43'}, 'reference': 'ChIJq6p6_sR_j4ARpC7fCj77Z4A', 'scope': 'GOOGLE', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'vicinity': '500 Terry A Francois Boulevard, San Francisco'} ...

# %%
p = search_places_by_coordinate(key='', 
                                     location='37.768831, -122.389311', 
                                     radius = 50, 
                                     types='transit_station')
print(p)
json_save_to_csv(places = p , filename="mission bay.csv")
# Out:
# page1 4
# 4
# [{'geometry': {'location': {'lat': 37.769049, 'lng': -122.389228}, 'viewport': {'northeast': {'lat': 37.7703964302915, 'lng': -122.3879056697085}, 'southwest': {'lat': 37.7676984697085, 'lng': -122.3906036302915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': '58b9d0b4d8fe296610cdc04df496df7614c2fb60', 'name': '3rd St & Warriors Way', 'place_id': 'ChIJRQOYd8V_j4AR_GMaQVtauGs', 'plus_code': {'compound_code': 'QJ96+J8 SoMa, San Francisco, CA, United States', 'global_code': '849VQJ96+J8'}, 'reference': 'ChIJRQOYd8V_j4AR_GMaQVtauGs', 'scope': 'GOOGLE', 'types': ['transit_station', 'point_of_interest', 'establishment'], 'vicinity': 'United States'}, {'geometry': {'location': {'lat': 37.7684738, 'lng': -122.3893215}, 'viewport': {'northeast': {'lat': 37.76982253029151, 'lng': -122.3879765697085}, 'southwest': {'lat': 37.76712456970851, 'lng': -122.3906745302915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': '92acbe432c496092cba84610fe1937eaf2e0635b', 'name': 'UCSF Mission Bay', 'place_id': 'ChIJkWtBksV_j4ARfmukO2BxuAA', 'plus_code': {'compound_code': 'QJ96+97 SoMa, San Francisco, CA, United States', 'global_code': '849VQJ96+97'}, 'rating': 4, 'reference': 'ChIJkWtBksV_j4ARfmukO2BxuAA', 'scope': 'GOOGLE', 'types': ['transit_station', 'point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': 'United States'}, {'geometry': {'location': {'lat': 37.76920969999999, 'lng': -122.3892901}, 'viewport': {'northeast': {'lat': 37.7706627802915, 'lng': -122.3879199197085}, 'southwest': {'lat': 37.7679648197085, 'lng': -122.3906178802915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'cfbdd50145f215507e3cc8658fb1e8dc5f65c97e', 'name': 'UCSF/Mission Bay', 'photos': [{'height': 1960, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114503919380903200117">LAM SON NGO</a>'], 'photo_reference': 'CmRZAAAA5XOlQqbcBV6fjmsLjMo0XqYO9m0VHZhXIY6cNx0YIa07AofpWdMH2wqDVYOe1kQCjF8NZgapGdr-PWzoAOJX4hxy974QovrhCIQIIvGhHLkpyq11iD-8HQ2JpuEmmSOFEhD5V5rWvWIQei4t39sE4EJDGhTe4d01K-TsvxDMsHotGEcmW3Jq2A', 'width': 4032}], 'place_id': 'ChIJ-SY8m8V_j4ARrHQIbCkouPk', 'plus_code': {'compound_code': 'QJ96+M7 SoMa, San Francisco, CA, United States', 'global_code': '849VQJ96+M7'}, 'rating': 3.7, 'reference': 'ChIJ-SY8m8V_j4ARrHQIbCkouPk', 'scope': 'GOOGLE', 'types': ['transit_station', 'point_of_interest', 'establishment'], 'user_ratings_total': 3, 'vicinity': '3rd Street, San Francisco'}, {'geometry': {'location': {'lat': 37.7684188, 'lng': -122.3893229}, 'viewport': {'northeast': {'lat': 37.76976793029149, 'lng': -122.3879713697085}, 'southwest': {'lat': 37.76706996970849, 'lng': -122.3906693302915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': '0b95d1d4f0dead35588f0f2c1f238ffeda10baaf', 'name': 'UCSF Mission Bay', 'place_id': 'ChIJwbgUbtd-j4ARYNvI5bjV2rg', 'plus_code': {'compound_code': 'QJ96+97 SoMa, San Francisco, CA, United States', 'global_code': '849VQJ96+97'}, 'reference': 'ChIJwbgUbtd-j4ARYNvI5bjV2rg', 'scope': 'GOOGLE', 'types': ['light_rail_station', 'transit_station', 'point_of_interest', 'establishment'], 'vicinity': 'United States'}]

# %%
# search for restaurants near 19th Oakland BART station
p = search_places_by_coordinate(key='', 
                                     location='37.809215, -122.267250', 
                                     radius = 300, 
                                     types='restaurant')
# print(p)
json_save_to_csv(places = p , filename="19th_restaurant.csv")
# Out:
# page1 20
# all pages 44

# %%
# Define client
# key='AIzaSyA1xZe9LinjV7wT4WMNEdIFL-38AgbkE0E'

#Define our Search

####### search for transit ###########

for index, rows in locs.iterrows():
    latitude =rows.Lat
    longitude= rows.Lng
    location_point = str(latitude) + ',' +str(longitude)
    location = rows.Location
    print(location)
    print(location_point)
    # search for transit types
    p = []
    for transit in transit_list:
        print(transit)
        p_i= search_places_by_coordinate(key='', 
                                         location=location_point, 
                                         radius = 805, 
                                         types= transit)
        p.extend(p_i)
#     print(p)
    json_save_to_csv(places = p , filename='data/transit/'+str(location)+"_transit.csv")
# Out:
# Mission Bay
# 37.76883056,-122.3893111
# bus_station
# page1 4
# all pages 4
# light_rail_station
# page1 7
# all pages 7
# subway_station
# page1 0
# all pages 0
# train_station
# page1 0
# all pages 0
# transit_station
# page1 20
# all pages 45
# Hayes Valley
# 37.77686111,-122.42333329999998
# bus_station
# page1 20
# all pages 32
# light_rail_station
# page1 10
# all pages 10
# subway_station
# page1 0
# all pages 0
# train_station
# page1 0
# all pages 0
# transit_station
# page1 20
# all pages 60
# Kendall Square
# 42.36243611,-71.0862
# bus_station
# page1 2
# all pages 2
# light_rail_station
# page1 0
# all pages 0
# subway_station
# page1 1
# all pages 1
# train_station
# page1 0
# all pages 0
# transit_station
# page1 20
# all pages 32
# Pearl District
# 45.52659444,-122.68229720000001
# bus_station
# page1 5
# all pages 5
# light_rail_station
# page1 20
# all pages 23
# subway_station
# page1 0
# all pages 0
# train_station
# page1 1
# all pages 1
# transit_station
# page1 20
# all pages 60
# Uptown Oakland
# 37.80893889,-122.26849440000001
# bus_station
# page1 17
# all pages 17
# light_rail_station
# page1 0
# all pages 0
# subway_station
# page1 2
# all pages 2
# train_station
# page1 0
# all pages 0
# transit_station
# page1 20
# all pages 60
# Grand Lake
# 37.81038889,-122.24693329999998
# bus_station
# page1 1
# all pages 1
# light_rail_station
# page1 0
# all pages 0
# subway_station
# page1 0
# all pages 0
# train_station
# page1 0
# all pages 0
# transit_station
# page1 20
# all pages 56

# %%
# Define client
# key='AIzaSyA1xZe9LinjV7wT4WMNEdIFL-38AgbkE0E'

#Define our Search


for index, rows in locs.iterrows():
    latitude =rows.Lat
    longitude= rows.Lng
    location_point = str(latitude) + ',' +str(longitude)
    location = rows.Location
    print(location)
    print(location_point)
    # search for retail types
    p = []
    for retail in retail_list:
        print(retail)
        p_i= search_places_by_coordinate(key='', 
                                         location=location_point, 
                                         radius = 805, 
                                         types= retail)
        p.extend(p_i)
#     print(p)
    json_save_to_csv(places = p , filename='data/retail/'+str(location)+"_retail.csv")
# Out:
# Mission Bay
# 37.76883056,-122.3893111
# art_gallery
# page1 9
# all pages 9
# bakery
# page1 5
# all pages 5
# bank
# page1 3
# all pages 3
# bar
# page1 8
# all pages 8
# beauty_salon
# page1 11
# all pages 11
# bicycle_store
# page1 1
# all pages 1
# book_store
# page1 1
# all pages 1
# bowling_alley
# page1 0
# all pages 0
# cafe
# page1 19
# all pages 19
# clothing_store
# page1 17
# all pages 17
# convenience_store
# page1 0
# all pages 0
# department_store
# page1 1
# all pages 1
# drugstore
# page1 0
# all pages 0
# electronics_store
# page1 10
# all pages 10
# florist
# page1 1
# all pages 1
# furniture_store
# page1 2
# all pages 2
# grocery_or_supermarket
# page1 0
# all pages 0
# gym
# page1 20
# all pages 22
# hair_care
# page1 5
# all pages 5
# hardware_store
# page1 1
# all pages 1
# home_goods_store
# page1 20
# all pages 25
# jewelry_store
# page1 5
# all pages 5
# liquor_store
# page1 1
# all pages 1
# meal_takeaway
# page1 4
# all pages 4
# movie_rental
# page1 0
# all pages 0
# movie_theater
# page1 0
# all pages 0
# museum
# page1 3
# all pages 3
# night_club
# page1 1
# all pages 1
# pharmacy
# page1 4
# all pages 4
# pet_store
# page1 1
# all pages 1
# restaurant
# page1 20
# all pages 39
# shoe_store
# page1 2
# all pages 2
# shopping_mall
# page1 0
# all pages 0
# spa
# page1 6
# all pages 6
# store
# page1 20
# all pages 60
# supermarket
# page1 0
# all pages 0
# Hayes Valley
# 37.77686111,-122.42333329999998
# art_gallery
# page1 19
# all pages 19
# bakery
# page1 18
# all pages 18
# bank
# page1 9
# all pages 9
# bar
# page1 20
# all pages 44
# beauty_salon
# page1 20
# all pages 27
# bicycle_store
# page1 2
# all pages 2
# book_store
# page1 9
# all pages 9
# bowling_alley
# page1 0
# all pages 0
# cafe
# page1 20
# all pages 55
# clothing_store
# page1 20
# all pages 58
# convenience_store
# page1 12
# all pages 12
# department_store
# page1 0
# all pages 0
# drugstore
# page1 5
# all pages 5
# electronics_store
# page1 20
# all pages 31
# florist
# page1 4
# all pages 4
# furniture_store
# page1 13
# all pages 13
# grocery_or_supermarket
# page1 4
# all pages 4
# gym
# page1 20
# all pages 30
# hair_care
# page1 20
# all pages 34
# hardware_store
# page1 1
# all pages 1
# home_goods_store
# page1 20
# all pages 60
# jewelry_store
# page1 12
# all pages 12
# liquor_store
# page1 16
# all pages 16
# meal_takeaway
# page1 17
# all pages 17
# movie_rental
# page1 0
# all pages 0
# movie_theater
# page1 3
# all pages 3
# museum
# page1 4
# all pages 4
# night_club
# page1 14
# all pages 14
# pharmacy
# page1 18
# all pages 18
# pet_store
# page1 0
# all pages 0
# restaurant
# page1 20
# all pages 60
# shoe_store
# page1 6
# all pages 6
# shopping_mall
# page1 17
# all pages 17
# spa
# page1 9
# all pages 9
# store
# page1 20
# all pages 60
# supermarket
# page1 4
# all pages 4
# Kendall Square
# 42.36243611,-71.0862
# art_gallery
# page1 4
# all pages 4
# bakery
# page1 6
# all pages 6
# bank
# page1 7
# all pages 7
# bar
# page1 20
# all pages 21
# beauty_salon
# page1 2
# all pages 2
# bicycle_store
# page1 0
# all pages 0
# book_store
# page1 0
# all pages 0
# bowling_alley
# page1 0
# all pages 0
# cafe
# page1 20
# all pages 25
# clothing_store
# page1 3
# all pages 3
# convenience_store
# page1 3
# all pages 3
# department_store
# page1 0
# all pages 0
# drugstore
# page1 0
# all pages 0
# electronics_store
# page1 7
# all pages 7
# florist
# page1 1
# all pages 1
# furniture_store
# page1 0
# all pages 0
# grocery_or_supermarket
# page1 0
# all pages 0
# gym
# page1 8
# all pages 8
# hair_care
# page1 5
# all pages 5
# hardware_store
# page1 1
# all pages 1
# home_goods_store
# page1 5
# all pages 5
# jewelry_store
# page1 0
# all pages 0
# liquor_store
# page1 1
# all pages 1
# meal_takeaway
# page1 4
# all pages 4
# movie_rental
# page1 0
# all pages 0
# movie_theater
# page1 2
# all pages 2
# museum
# page1 4
# all pages 4
# night_club
# page1 2
# all pages 2
# pharmacy
# page1 2
# all pages 2
# pet_store
# page1 1
# all pages 1
# restaurant
# page1 20
# all pages 60
# shoe_store
# page1 0
# all pages 0
# shopping_mall
# page1 1
# all pages 1
# spa
# page1 1
# all pages 1
# store
# page1 20
# all pages 58
# supermarket
# page1 0
# all pages 0
# Pearl District
# 45.52659444,-122.68229720000001
# art_gallery
# page1 20
# all pages 60
# bakery
# page1 20
# all pages 23
# bank
# page1 20
# all pages 29
# bar
# page1 20
# all pages 60
# beauty_salon
# page1 20
# all pages 60
# bicycle_store
# page1 4
# all pages 4
# book_store
# page1 10
# all pages 10
# bowling_alley
# page1 0
# all pages 0
# cafe
# page1 20
# all pages 60
# clothing_store
# page1 20
# all pages 60
# convenience_store
# page1 15
# all pages 15
# department_store
# page1 1
# all pages 1
# drugstore
# page1 3
# all pages 3
# electronics_store
# page1 20
# all pages 27
# florist
# page1 16
# all pages 16
# furniture_store
# page1 20
# all pages 33
# grocery_or_supermarket
# page1 3
# all pages 3
# gym
# page1 20
# all pages 34
# hair_care
# page1 20
# all pages 60
# hardware_store
# page1 3
# all pages 3
# home_goods_store
# page1 20
# all pages 60
# jewelry_store
# page1 20
# all pages 26
# liquor_store
# page1 12
# all pages 12
# meal_takeaway
# page1 20
# all pages 20
# movie_rental
# page1 2
# all pages 2
# movie_theater
# page1 2
# all pages 2
# museum
# page1 10
# all pages 10
# night_club
# page1 20
# all pages 30
# pharmacy
# page1 12
# all pages 12
# pet_store
# page1 2
# all pages 2
# restaurant
# page1 20
# all pages 60
# shoe_store
# page1 20
# all pages 20
# shopping_mall
# page1 2
# all pages 2
# spa
# page1 20
# all pages 60
# store
# page1 20
# all pages 60
# supermarket
# page1 3
# all pages 3
# Uptown Oakland
# 37.80893889,-122.26849440000001
# art_gallery
# page1 20
# all pages 47
# bakery
# page1 16
# all pages 16
# bank
# page1 20
# all pages 32
# bar
# page1 20
# all pages 60
# beauty_salon
# page1 20
# all pages 43
# bicycle_store
# page1 2
# all pages 2
# book_store
# page1 11
# all pages 11
# bowling_alley
# page1 0
# all pages 0
# cafe
# page1 20
# all pages 60
# clothing_store
# page1 20
# all pages 46
# convenience_store
# page1 10
# all pages 10
# department_store
# page1 1
# all pages 1
# drugstore
# page1 3
# all pages 3
# electronics_store
# page1 19
# all pages 19
# florist
# page1 9
# all pages 9
# furniture_store
# page1 6
# all pages 6
# grocery_or_supermarket
# page1 3
# all pages 3
# gym
# page1 20
# all pages 23
# hair_care
# page1 20
# all pages 49
# hardware_store
# page1 0
# all pages 0
# home_goods_store
# page1 20
# all pages 52
# jewelry_store
# page1 11
# all pages 11
# liquor_store
# page1 7
# all pages 7
# meal_takeaway
# page1 17
# all pages 17
# movie_rental
# page1 1
# all pages 1
# movie_theater
# page1 3
# all pages 3
# museum
# page1 5
# all pages 5
# night_club
# page1 14
# all pages 14
# pharmacy
# page1 20
# all pages 21
# pet_store
# page1 0
# all pages 0
# restaurant
# page1 20
# all pages 60
# shoe_store
# page1 2
# all pages 2
# shopping_mall
# page1 6
# all pages 6
# spa
# page1 13
# all pages 13
# store
# page1 20
# all pages 60
# supermarket
# page1 3
# all pages 3
# Grand Lake
# 37.81038889,-122.24693329999998
# art_gallery
# page1 4
# all pages 4
# bakery
# page1 5
# all pages 5
# bank
# page1 5
# all pages 5
# bar
# page1 16
# all pages 16
# beauty_salon
# page1 20
# all pages 54
# bicycle_store
# page1 2
# all pages 2
# book_store
# page1 3
# all pages 3
# bowling_alley
# page1 0
# all pages 0
# cafe
# page1 16
# all pages 16
# clothing_store
# page1 14
# all pages 14
# convenience_store
# page1 6
# all pages 6
# department_store
# page1 0
# all pages 0
# drugstore
# page1 1
# all pages 1
# electronics_store
# page1 14
# all pages 14
# florist
# page1 5
# all pages 5
# furniture_store
# page1 4
# all pages 4
# grocery_or_supermarket
# page1 1
# all pages 1
# gym
# page1 20
# all pages 21
# hair_care
# page1 20
# all pages 33
# hardware_store
# page1 0
# all pages 0
# home_goods_store
# page1 20
# all pages 28
# jewelry_store
# page1 4
# all pages 4
# liquor_store
# page1 6
# all pages 6
# meal_takeaway
# page1 6
# all pages 6
# movie_rental
# page1 2
# all pages 2
# movie_theater
# page1 1
# all pages 1
# museum
# page1 0
# all pages 0
# night_club
# page1 3
# all pages 3
# pharmacy
# page1 3
# all pages 3
# pet_store
# page1 0
# all pages 0
# restaurant
# page1 20
# all pages 60
# shoe_store
# page1 2
# all pages 2
# shopping_mall
# page1 1
# all pages 1
# spa
# page1 20
# all pages 21
# store
# page1 20
# all pages 60
# supermarket
# page1 1
# all pages 1
